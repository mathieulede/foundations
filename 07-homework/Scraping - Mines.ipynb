# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm#MID), thank goodness we can search for these things.

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.
#
# **Search for every operator with 'dirt' in their name, including abandoned mines.**

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
# Each row is a <tr> tag without class

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# Every mine operator's name in a <font> tag within a <td> tag and has no class

# %% [markdown]
# ### What is the tag and class name for every mine's name?

# %%
# Every mine's name in a <font> tag within a <td> tag and has no class

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# Every mine operator's name in a <font> tag within a <td> tag and has no class

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# Every mine operator's name in a <font> tag within a <td> tag and has no class

# %% [markdown]
# ## Being lazy
#
# If you only needed these results, what would you do instead of scraping them?

# %%
# copy-past into Excel

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[-1].text` to get the text of the last `<tr>` element.
#
# - If the result starts with **Total Number of Mines Found**, you were successful.

# %%
base_url = 'https://arlweb.msha.gov/drs/ASP/OprNameStatesearch.asp'
data = {
    'OperSearch': '',
    'MineName':'dirt',
    'StateSearch':'None',
    'CM':'All',
    'x':'21',
    'y':'9',
    'MC':'Opersearch'
}

# %%
response = requests.post(base_url, data=data)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc.find_all('tr')[-1].text.strip()
# Out:
# 'Total Number of Mines Found:\xa0\xa077'

# %% [markdown]
# ## Actually scraping

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %%
doc.find_all('tr')[7]
# Out:
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# Use LIST SLICING to skip the non-data row(s).

# %%
for t in doc.find_all('th', attrs={'bgcolor':'#000000'}):
    print(t.find_parent().find_all('td')[3].text.strip())
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Co Pit & Plant
# AM Dirtworks & Aggregate Sales
# Bar-Lin Dirt Pit
# Barber'S Dirt Pit
# Pay Dirt
# BENDER SAND & DIRT
# BERT'S DIRT
# Big Red Dirt Farm
# Big River Dirt Pit
# BOHANNON SAND & DIRT
# Buck'S Dirt Pit
# 17-A DIRT PIT
# PAYDIRT #1
# Dirt Crew 1
# Dirt Crew # 2
# Crowes Dirt Pit
# D & H Dirt
# WISE DIRT
# Dirt Cheap
# THE DIRT PIT
# DIRTCO INC
# Dirtman Sand & Gravel #2
# DIRTWORKS, INC.
# Dirtworks, Inc.
# Eddie Carr Dirt LLC
# DIRT/SAND SCREEN-AASE PIT
# Floyd Smith Dirt Pit
# Greer Dirt Pit
# Guidry Sand & Dirt Pit
# Dirt Pit
# Harris Dirt Pit
# Hatchet Creek Rock & Dirt LLC
# Dirt Pit
# Iske Dirt Sand & Gravel
# Cowan Dirt Pit #1 & #2
# Cowan Dirt Pit
# COWAN DIRT PIT #3
# Stephens Red Dirt Farm
# Cowan Dirt Pit # 4
# Pay Dirt
# Trainer Dirt Pit
# L I P Dirt & Trucking
# La Amite Dirt Pit
# Lee'S Dirt Pit
# Dirt Dumper
# Lowe Dirt Pit
# Lowe Dirt Pit
# Little-G-Dirt Pit
# Long'S Dirt Pit
# MARCELO DIRT-LOAM
# Maurice Dirt And Sand
# Moss Dirt Pit
# Nelson & Sons Dirt Haulers Incorporated
# NELSON'S DIRT PIT
# Dirty Ike Quarry
# R D BLANKENSHIP DIRT WORK
# Reeves Dirt Pit Incorporated
# EGeria Dirt Pit
# River Bottom Dirt
# Rodosta Dirt Pit
# Roe'S Dirt Pit
# Roe'S Dirt Pit
# J. V. DIRT & LOAM
# Sierra Rock & Dirt Inc
# Southside Dirt Pit
# Stewart Dirt Work Inc - Hanna Pit
# Suncoast Dirt Pit
# Surrey Dirt Pit
# Highway 642 Dirt Pit
# Rock-N-Dirt
# Toler Roe Dirt Pit
# Pay Dirt North Incline
# Bunk Dirt Pit
# Southside Dirt Pit
# Withrow'S Dirt Pit
# Yarbrough Dirt Pit #1

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for t in doc.find_all('th', attrs={'bgcolor':'#000000'}):
    print(t.find_parent().find_all('td')[0].text.strip())
# Out:
# 3503598
# 0502030
# 4801789
# 1601167
# 4103265
# 2601714
# 1401575
# 1700776
# 0301963
# 1601082
# 1600916
# 1600956
# 3800631
# 3401803
# 1302275
# 1302409
# 1601106
# 3400915
# 4104192
# 4503200
# 4104016
# 0301729
# 0404851
# 2200734
# 5002028
# 2200637
# 1301775
# 3401762
# 4103577
# 1601124
# 1600801
# 1601150
# 4703427
# 0405187
# 2501216
# 1600761
# 1600954
# 1601271
# 0301890
# 1601391
# 0202046
# 1601163
# 1601250
# 1600950
# 1600908
# 1601196
# 1600899
# 1601049
# 1600953
# 4102999
# 4103597
# 1601257
# 1601165
# 1601194
# 4104054
# 2401288
# 2901986
# 1601127
# 3800655
# 4105017
# 1600980
# 1600986
# 1600951
# 4103211
# 2402115
# 1601159
# 4104475
# 0801388
# 1601178
# 3800617
# 4104618
# 1601234
# 4801174
# 1601131
# 1600952
# 1601162
# 4103264

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
mines = []

for t in doc.find_all('th', attrs={'bgcolor':'#000000'}):
    columns = t.find_parent().find_all('td')
    mines.append(
    {
        'Operator ID': columns[0].text.strip(),
        'Operator name': columns[2].text.strip(),
        'Mine name': columns[3].text.strip(),
        'State': columns[1].text.strip(),
        'Mine type': columns[4].text.strip(),
        'Coal or metal': columns[5].text.strip(),
        'Status': columns[6].text.strip(),
        'Commodity': columns[7].text.strip()
    })

mines
# Out:
# [{'Coal or metal': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'Mine name': 'Newberg Rock & Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '3503598',
#   'Operator name': 'Newberg Rock & Dirt',
#   'State': 'OR',
#   'Status': 'Active'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Allied Dirt Moving Co Pit & Plant',
#   'Mine type': 'Surface',
#   'Operator ID': '0502030',
#   'Operator name': 'Allied Dirt Moving Company',
#   'State': 'CO',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'AM Dirtworks & Aggregate Sales',
#   'Mine type': 'Surface',
#   'Operator ID': '4801789',
#   'Operator name': 'AM Dirtworks & Aggregate Sales',
#   'State': 'ND',
#   'Status': 'Intermittent'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Bar-Lin Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601167',
#   'Operator name': 'Bar-Lin Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Barber'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '4103265',
#   'Operator name': "Barber'S Dirt Pit",
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Gold Ore',
#   'Mine name': 'Pay Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '2601714',
#   'Operator name': 'Basil Cramer',
#   'State': 'NV',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'BENDER SAND & DIRT',
#   'Mine type': 'Surface',
#   'Operator ID': '1401575',
#   'Operator name': 'Bender Sand & Dirt',
#   'State': 'KS',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "BERT'S DIRT",
#   'Mine type': 'Surface',
#   'Operator ID': '1700776',
#   'Operator name': "BERT'S DIRT",
#   'State': 'ME',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Big Red Dirt Farm',
#   'Mine type': 'Surface',
#   'Operator ID': '0301963',
#   'Operator name': 'Big Red Dirt Farm LLC',
#   'State': 'AR',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Big River Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601082',
#   'Operator name': 'Big River Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'BOHANNON SAND & DIRT',
#   'Mine type': 'Surface',
#   'Operator ID': '1600916',
#   'Operator name': 'Bohannon Sand & Dirt',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Buck'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '1600956',
#   'Operator name': "Buck'S Dirt Pit",
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': '17-A DIRT PIT',
#   'Mine type': 'Surface',
#   'Operator ID': '3800631',
#   'Operator name': 'Butler Ware Trucking Inc',
#   'State': 'SC',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'PAYDIRT #1',
#   'Mine type': 'Surface',
#   'Operator ID': '3401803',
#   'Operator name': 'Chisholm Trail Mining Company',
#   'State': 'OK',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirt Crew 1',
#   'Mine type': 'Surface',
#   'Operator ID': '1302275',
#   'Operator name': 'Croell, Inc.',
#   'State': 'IA',
#   'Status': 'Intermittent'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirt Crew # 2',
#   'Mine type': 'Surface',
#   'Operator ID': '1302409',
#   'Operator name': 'Croell, Inc.',
#   'State': 'IA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Crowes Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601106',
#   'Operator name': 'Crowes Trucking & Dirt Pit Services',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'D & H Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '3400915',
#   'Operator name': 'D & H Dirt',
#   'State': 'OK',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'WISE DIRT',
#   'Mine type': 'Surface',
#   'Operator ID': '4104192',
#   'Operator name': 'D-6 Enterprises Inc',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Common Clays NEC',
#   'Mine name': 'Dirt Cheap',
#   'Mine type': 'Surface',
#   'Operator ID': '4503200',
#   'Operator name': 'Dirt Cheap',
#   'State': 'WA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'THE DIRT PIT',
#   'Mine type': 'Surface',
#   'Operator ID': '4104016',
#   'Operator name': 'Dirt Pit',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'DIRTCO INC',
#   'Mine type': 'Surface',
#   'Operator ID': '0301729',
#   'Operator name': 'Dirtco Inc',
#   'State': 'AR',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirtman Sand & Gravel #2',
#   'Mine type': 'Surface',
#   'Operator ID': '0404851',
#   'Operator name': 'Dirtman Trucking',
#   'State': 'CA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'DIRTWORKS, INC.',
#   'Mine type': 'Surface',
#   'Operator ID': '2200734',
#   'Operator name': 'DIRTWORKS, INC.',
#   'State': 'MS',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirtworks, Inc.',
#   'Mine type': 'Surface',
#   'Operator ID': '5002028',
#   'Operator name': 'Dirtworks, Inc.',
#   'State': 'AK',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Eddie Carr Dirt LLC',
#   'Mine type': 'Surface',
#   'Operator ID': '2200637',
#   'Operator name': 'Eddie Carr',
#   'State': 'MS',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'DIRT/SAND SCREEN-AASE PIT',
#   'Mine type': 'Surface',
#   'Operator ID': '1301775',
#   'Operator name': 'FALKSTONE LLC',
#   'State': 'IA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Dimension Stone NEC',
#   'Mine name': 'Floyd Smith Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '3401762',
#   'Operator name': 'Floyd Smith Dirt Pit',
#   'State': 'OK',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Greer Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '4103577',
#   'Operator name': 'Greer Equipment Company',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Guidry Sand & Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601124',
#   'Operator name': 'Guidry Sand & Dirt Pit Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600801',
#   'Operator name': 'H & L Land Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Harris Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601150',
#   'Operator name': 'Harris Dirt Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Hatchet Creek Rock & Dirt LLC',
#   'Mine type': 'Surface',
#   'Operator ID': '4703427',
#   'Operator name': 'Hatchet Creek Rock & Dirt LLC',
#   'State': 'WI',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '0405187',
#   'Operator name': 'Hofer & Sons',
#   'State': 'CA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Iske Dirt Sand & Gravel',
#   'Mine type': 'Surface',
#   'Operator ID': '2501216',
#   'Operator name': 'Iske Dirt Sand & Gravel',
#   'State': 'NE',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Cowan Dirt Pit #1 & #2',
#   'Mine type': 'Surface',
#   'Operator ID': '1600761',
#   'Operator name': 'J K Cowan Sr Contracting Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Cowan Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600954',
#   'Operator name': 'J K Cowan Sr Contracting Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'COWAN DIRT PIT #3',
#   'Mine type': 'Surface',
#   'Operator ID': '1601271',
#   'Operator name': 'J K Cowan Sr Contracting Company Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'Mine name': 'Stephens Red Dirt Farm',
#   'Mine type': 'Surface',
#   'Operator ID': '0301890',
#   'Operator name': 'J&A; Mining, LLC',
#   'State': 'AR',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Cowan Dirt Pit # 4',
#   'Mine type': 'Surface',
#   'Operator ID': '1601391',
#   'Operator name': 'J. K. Cowan Sr. Contracting Co., Inc.',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Gold Ore',
#   'Mine name': 'Pay Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '0202046',
#   'Operator name': 'John O Clay Exploration Inc',
#   'State': 'AZ',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Trainer Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601163',
#   'Operator name': 'Kat Wireline Farm Account',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'L I P Dirt & Trucking',
#   'Mine type': 'Surface',
#   'Operator ID': '1601250',
#   'Operator name': 'L I P Dirt & Trucking',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'La Amite Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600950',
#   'Operator name': 'La Amite Place Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Lee'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '1600908',
#   'Operator name': "Lee'S Dirt Pit Inc",
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Dirt Dumper',
#   'Mine type': 'Surface',
#   'Operator ID': '1601196',
#   'Operator name': 'Leo Nelson',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Lowe Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600899',
#   'Operator name': 'Leon Lowe & Sons Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Lowe Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601049',
#   'Operator name': 'Leon Lowe & Sons Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Little-G-Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600953',
#   'Operator name': 'Little-G-Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Long'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '4102999',
#   'Operator name': "Long'S Dump Truck Services",
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'MARCELO DIRT-LOAM',
#   'Mine type': 'Surface',
#   'Operator ID': '4103597',
#   'Operator name': "Marcelo'S Inc",
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Maurice Dirt And Sand',
#   'Mine type': 'Surface',
#   'Operator ID': '1601257',
#   'Operator name': 'Maurice Dirt & Sand',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Moss Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601165',
#   'Operator name': 'Moss Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Nelson & Sons Dirt Haulers Incorporated',
#   'Mine type': 'Surface',
#   'Operator ID': '1601194',
#   'Operator name': 'Nelson & Sons Dirt Haulers Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "NELSON'S DIRT PIT",
#   'Mine type': 'Surface',
#   'Operator ID': '4104054',
#   'Operator name': "Nelson'S Dirt Pit",
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Crushed, Broken Sandstone',
#   'Mine name': 'Dirty Ike Quarry',
#   'Mine type': 'Surface',
#   'Operator ID': '2401288',
#   'Operator name': 'Phillips Construction Company Inc',
#   'State': 'MT',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'R D BLANKENSHIP DIRT WORK',
#   'Mine type': 'Surface',
#   'Operator ID': '2901986',
#   'Operator name': 'R D Blankenship Dirt Work LLC',
#   'State': 'NM',
#   'Status': 'Active'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Reeves Dirt Pit Incorporated',
#   'Mine type': 'Surface',
#   'Operator ID': '1601127',
#   'Operator name': 'Reeves Dirt Pit Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Sand, Industrial NEC',
#   'Mine name': 'EGeria Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '3800655',
#   'Operator name': 'Risher Mining Inc',
#   'State': 'SC',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Sand, Common',
#   'Mine name': 'River Bottom Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '4105017',
#   'Operator name': 'River Bottom Dirt',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Rodosta Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600980',
#   'Operator name': 'Rodosta Brothers Contractors Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Roe'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '1600986',
#   'Operator name': "Roe'S Dirt Pit",
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Roe'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '1600951',
#   'Operator name': "Roe'S Inc",
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'J. V. DIRT & LOAM',
#   'Mine type': 'Surface',
#   'Operator ID': '4103211',
#   'Operator name': 'Service Holdings Inc',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Sierra Rock & Dirt Inc',
#   'Mine type': 'Surface',
#   'Operator ID': '2402115',
#   'Operator name': 'Sierra Rock & Dirt, Inc.',
#   'State': 'MT',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Southside Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601159',
#   'Operator name': 'Southside Dirt Company',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Crushed, Broken Stone NEC',
#   'Mine name': 'Stewart Dirt Work Inc - Hanna Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '4104475',
#   'Operator name': 'Stewart Dirt Work, Inc.',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Sand, Common',
#   'Mine name': 'Suncoast Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '0801388',
#   'Operator name': 'Suncoast Concrete, Inc.',
#   'State': 'FL',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Surrey Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601178',
#   'Operator name': 'Surrey Corp',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Highway 642 Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '3800617',
#   'Operator name': "Sweat'S Dirt Hauling Inc",
#   'State': 'SC',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Rock-N-Dirt',
#   'Mine type': 'Surface',
#   'Operator ID': '4104618',
#   'Operator name': 'The Wishbone Ranch',
#   'State': 'TX',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Toler Roe Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601234',
#   'Operator name': 'Toler Roe Dirt Pit',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Uranium Ore',
#   'Mine name': 'Pay Dirt North Incline',
#   'Mine type': 'Underground',
#   'Operator ID': '4801174',
#   'Operator name': 'U S Energy Corp',
#   'State': 'WY',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Bunk Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1601131',
#   'Operator name': 'W C Hoyt',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Southside Dirt Pit',
#   'Mine type': 'Surface',
#   'Operator ID': '1600952',
#   'Operator name': 'Waste Not Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': "Withrow'S Dirt Pit",
#   'Mine type': 'Surface',
#   'Operator ID': '1601162',
#   'Operator name': 'Withrow Enterprise Inc',
#   'State': 'LA',
#   'Status': 'Abandoned'},
#  {'Coal or metal': 'M',
#   'Commodity': 'Construction Sand and Gravel',
#   'Mine name': 'Yarbrough Dirt Pit #1',
#   'Mine type': 'Surface',
#   'Operator ID': '4103264',
#   'Operator name': 'Yarbrough Dirt Pit Inc',
#   'State': 'TX',
#   'Status': 'Abandoned'}]

# %% [markdown]
# ### Save that to a CSV

# %%
df = pd.DataFrame(mines)
df.to_csv('mines.csv')

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('mines.csv')
# Out:
#     Unnamed: 0 Coal or metal                     Commodity  \
# 0            0             M     Crushed, Broken Stone NEC
# 1            1             M  Construction Sand and Gravel
# 2            2             M  Construction Sand and Gravel
# 3            3             M  Construction Sand and Gravel
# 4            4             M  Construction Sand and Gravel
# 5            5             M                      Gold Ore
# 6            6             M  Construction Sand and Gravel
# 7            7             M  Construction Sand and Gravel
# 8            8             M  Construction Sand and Gravel
# 9            9             M  Construction Sand and Gravel
# 10          10             M  Construction Sand and Gravel
# 11          11             M  Construction Sand and Gravel
# 12          12             M  Construction Sand and Gravel
# 13          13             M  Construction Sand and Gravel
# 14          14             M  Construction Sand and Gravel
# 15          15             M  Construction Sand and Gravel
# 16          16             M  Construction Sand and Gravel
# 17          17             M  Construction Sand and Gravel
# 18          18             M  Construction Sand and Gravel
# 19          19             M              Common Clays NEC
# 20          20             M  Construction Sand and Gravel
# 21          21             M  Construction Sand and Gravel
# 22          22             M  Construction Sand and Gravel
# 23          23             M  Construction Sand and Gravel
# 24          24             M  Construction Sand and Gravel
# 25          25             M  Construction Sand and Gravel
# 26          26             M  Construction Sand and Gravel
# 27          27             M           Dimension Stone NEC
# 28          28             M  Construction Sand and Gravel
# 29          29             M  Construction Sand and Gravel
# ..         ...           ...                           ...
# 47          47             M  Construction Sand and Gravel
# 48          48             M  Construction Sand and Gravel
# 49          49             M  Construction Sand and Gravel
# 50          50             M  Construction Sand and Gravel
# 51          51             M  Construction Sand and Gravel
# 52          52             M  Construction Sand and Gravel
# 53          53             M  Construction Sand and Gravel
# 54          54             M  Construction Sand and Gravel
# 55          55             M     Crushed, Broken Sandstone
# 56          56             M  Construction Sand and Gravel
# 57          57             M  Construction Sand and Gravel
# 58          58             M          Sand, Industrial NEC
# 59          59             M                  Sand, Common
# 60          60             M  Construction Sand and Gravel
# 61          61             M  Construction Sand and Gravel
# 62          62             M  Construction Sand and Gravel
# 63          63             M  Construction Sand and Gravel
# 64          64             M  Construction Sand and Gravel
# 65          65             M  Construction Sand and Gravel
# 66          66             M     Crushed, Broken Stone NEC
# 67          67             M                  Sand, Common
# 68          68             M  Construction Sand and Gravel
# 69          69             M  Construction Sand and Gravel
# 70          70             M  Construction Sand and Gravel
# 71          71             M  Construction Sand and Gravel
# 72          72             M                   Uranium Ore
# 73          73             M  Construction Sand and Gravel
# 74          74             M  Construction Sand and Gravel
# 75          75             M  Construction Sand and Gravel
# 76          76             M  Construction Sand and Gravel
#
#                                   Mine name    Mine type  Operator ID  \
# 0                       Newberg Rock & Dirt      Surface      3503598
# 1         Allied Dirt Moving Co Pit & Plant      Surface       502030
# 2            AM Dirtworks & Aggregate Sales      Surface      4801789
# 3                          Bar-Lin Dirt Pit      Surface      1601167
# 4                         Barber'S Dirt Pit      Surface      4103265
# 5                                  Pay Dirt      Surface      2601714
# 6                        BENDER SAND & DIRT      Surface      1401575
# 7                               BERT'S DIRT      Surface      1700776
# 8                         Big Red Dirt Farm      Surface       301963
# 9                        Big River Dirt Pit      Surface      1601082
# 10                     BOHANNON SAND & DIRT      Surface      1600916
# 11                          Buck'S Dirt Pit      Surface      1600956
# 12                            17-A DIRT PIT      Surface      3800631
# 13                               PAYDIRT #1      Surface      3401803
# 14                              Dirt Crew 1      Surface      1302275
# 15                            Dirt Crew # 2      Surface      1302409
# 16                          Crowes Dirt Pit      Surface      1601106
# 17                               D & H Dirt      Surface      3400915
# 18                                WISE DIRT      Surface      4104192
# 19                               Dirt Cheap      Surface      4503200
# 20                             THE DIRT PIT      Surface      4104016
# 21                               DIRTCO INC      Surface       301729
# 22                 Dirtman Sand & Gravel #2      Surface       404851
# 23                          DIRTWORKS, INC.      Surface      2200734
# 24                          Dirtworks, Inc.      Surface      5002028
# 25                      Eddie Carr Dirt LLC      Surface      2200637
# 26                DIRT/SAND SCREEN-AASE PIT      Surface      1301775
# 27                     Floyd Smith Dirt Pit      Surface      3401762
# 28                           Greer Dirt Pit      Surface      4103577
# 29                   Guidry Sand & Dirt Pit      Surface      1601124
# ..                                      ...          ...          ...
# 47                            Lowe Dirt Pit      Surface      1601049
# 48                        Little-G-Dirt Pit      Surface      1600953
# 49                          Long'S Dirt Pit      Surface      4102999
# 50                        MARCELO DIRT-LOAM      Surface      4103597
# 51                    Maurice Dirt And Sand      Surface      1601257
# 52                            Moss Dirt Pit      Surface      1601165
# 53  Nelson & Sons Dirt Haulers Incorporated      Surface      1601194
# 54                        NELSON'S DIRT PIT      Surface      4104054
# 55                         Dirty Ike Quarry      Surface      2401288
# 56                R D BLANKENSHIP DIRT WORK      Surface      2901986
# 57             Reeves Dirt Pit Incorporated      Surface      1601127
# 58                          EGeria Dirt Pit      Surface      3800655
# 59                        River Bottom Dirt      Surface      4105017
# 60                         Rodosta Dirt Pit      Surface      1600980
# 61                           Roe'S Dirt Pit      Surface      1600986
# 62                           Roe'S Dirt Pit      Surface      1600951
# 63                        J. V. DIRT & LOAM      Surface      4103211
# 64                   Sierra Rock & Dirt Inc      Surface      2402115
# 65                       Southside Dirt Pit      Surface      1601159
# 66        Stewart Dirt Work Inc - Hanna Pit      Surface      4104475
# 67                        Suncoast Dirt Pit      Surface       801388
# 68                          Surrey Dirt Pit      Surface      1601178
# 69                     Highway 642 Dirt Pit      Surface      3800617
# 70                              Rock-N-Dirt      Surface      4104618
# 71                       Toler Roe Dirt Pit      Surface      1601234
# 72                   Pay Dirt North Incline  Underground      4801174
# 73                            Bunk Dirt Pit      Surface      1601131
# 74                       Southside Dirt Pit      Surface      1600952
# 75                       Withrow'S Dirt Pit      Surface      1601162
# 76                    Yarbrough Dirt Pit #1      Surface      4103264
#
#                           Operator name State        Status
# 0                   Newberg Rock & Dirt    OR        Active
# 1            Allied Dirt Moving Company    CO     Abandoned
# 2        AM Dirtworks & Aggregate Sales    ND  Intermittent
# 3                  Bar-Lin Dirt Company    LA     Abandoned
# 4                     Barber'S Dirt Pit    TX     Abandoned
# 5                          Basil Cramer    NV     Abandoned
# 6                    Bender Sand & Dirt    KS     Abandoned
# 7                           BERT'S DIRT    ME     Abandoned
# 8                 Big Red Dirt Farm LLC    AR     Abandoned
# 9                    Big River Dirt Pit    LA     Abandoned
# 10                 Bohannon Sand & Dirt    LA     Abandoned
# 11                      Buck'S Dirt Pit    LA     Abandoned
# 12             Butler Ware Trucking Inc    SC     Abandoned
# 13        Chisholm Trail Mining Company    OK     Abandoned
# 14                         Croell, Inc.    IA  Intermittent
# 15                         Croell, Inc.    IA     Abandoned
# 16  Crowes Trucking & Dirt Pit Services    LA     Abandoned
# 17                           D & H Dirt    OK     Abandoned
# 18                  D-6 Enterprises Inc    TX     Abandoned
# 19                           Dirt Cheap    WA     Abandoned
# 20                             Dirt Pit    TX     Abandoned
# 21                           Dirtco Inc    AR     Abandoned
# 22                     Dirtman Trucking    CA     Abandoned
# 23                      DIRTWORKS, INC.    MS     Abandoned
# 24                      Dirtworks, Inc.    AK     Abandoned
# 25                           Eddie Carr    MS     Abandoned
# 26                        FALKSTONE LLC    IA     Abandoned
# 27                 Floyd Smith Dirt Pit    OK     Abandoned
# 28              Greer Equipment Company    TX     Abandoned
# 29           Guidry Sand & Dirt Pit Inc    LA     Abandoned
# ..                                  ...   ...           ...
# 47                 Leon Lowe & Sons Inc    LA     Abandoned
# 48                    Little-G-Dirt Pit    LA     Abandoned
# 49           Long'S Dump Truck Services    TX     Abandoned
# 50                        Marcelo'S Inc    TX     Abandoned
# 51                  Maurice Dirt & Sand    LA     Abandoned
# 52                    Moss Dirt Company    LA     Abandoned
# 53       Nelson & Sons Dirt Haulers Inc    LA     Abandoned
# 54                    Nelson'S Dirt Pit    TX     Abandoned
# 55    Phillips Construction Company Inc    MT     Abandoned
# 56        R D Blankenship Dirt Work LLC    NM        Active
# 57                  Reeves Dirt Pit Inc    LA     Abandoned
# 58                    Risher Mining Inc    SC     Abandoned
# 59                    River Bottom Dirt    TX     Abandoned
# 60     Rodosta Brothers Contractors Inc    LA     Abandoned
# 61                       Roe'S Dirt Pit    LA     Abandoned
# 62                            Roe'S Inc    LA     Abandoned
# 63                 Service Holdings Inc    TX     Abandoned
# 64             Sierra Rock & Dirt, Inc.    MT     Abandoned
# 65               Southside Dirt Company    LA     Abandoned
# 66              Stewart Dirt Work, Inc.    TX     Abandoned
# 67              Suncoast Concrete, Inc.    FL     Abandoned
# 68                          Surrey Corp    LA     Abandoned
# 69             Sweat'S Dirt Hauling Inc    SC     Abandoned
# 70                   The Wishbone Ranch    TX     Abandoned
# 71                   Toler Roe Dirt Pit    LA     Abandoned
# 72                      U S Energy Corp    WY     Abandoned
# 73                             W C Hoyt    LA     Abandoned
# 74                        Waste Not Inc    LA     Abandoned
# 75               Withrow Enterprise Inc    LA     Abandoned
# 76               Yarbrough Dirt Pit Inc    TX     Abandoned
#
# [77 rows x 9 columns]
