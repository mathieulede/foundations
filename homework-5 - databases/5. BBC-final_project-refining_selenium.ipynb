# %%
import pandas as pd
import numpy as np
import re

# %%
df_critics = pd.read_csv('critics_final.csv', index_col='id')
df_films = pd.read_csv('films_selenium_raw.csv', index_col='id')
df_reviews = pd.read_csv('reviews_final.csv', index_col='id')
df_directors = pd.read_csv('directors_selenium_raw.csv', index_col='id')
df_directions = pd.read_csv('directions_final.csv', index_col='id')
df_genres = pd.read_csv('genres_final.csv', index_col='id')
df_countries = pd.read_csv('countries-psql.csv', index_col='id', keep_default_na=False)
df_continents = pd.read_csv('continents-psql.csv', index_col='id', keep_default_na=False)

# %%
df_genres[df_genres['film_id'] == 0]
# Out:
#       film_id     genre
# id
# 0           0     Drama
# 1401        0   Mystery
# 1402        0  Thriller

# %%
df_merged = (df_reviews
 .merge(df_critics, left_on='critic_id', right_index=True)
 .merge(df_films, left_on='film_id', right_index=True)
 .merge(df_directions, left_on='film_id', right_on='film_id')
 .merge(df_directors, left_on='director_id', right_index=True))

df_merged[df_merged['full_name'] == 'Alyssa Rosenberg'].sort_values('rank')
# Out:
#       critic_id  film_id  rank         full_name nationality_code  \
# 730         139       71     0  Alyssa Rosenberg               US
# 1309        139      213     1  Alyssa Rosenberg               US
# 308         139       18     2  Alyssa Rosenberg               US
# 221         139       12     3  Alyssa Rosenberg               US
# 765         139       77     4  Alyssa Rosenberg               US
# 909         139       97     5  Alyssa Rosenberg               US
# 1614        139      366     6  Alyssa Rosenberg               US
# 490         139       39     7  Alyssa Rosenberg               US
# 1432        139      267     8  Alyssa Rosenberg               US
# 1850        139      525     9  Alyssa Rosenberg               US
#
#                   company                           title  year  rating  \
# 730   The Washington Post                          Zodiac  2007     7.7
# 1309  The Washington Post  Crouching Tiger, Hidden Dragon  2000     7.9
# 308   The Washington Post                Zero Dark Thirty  2012     7.4
# 221   The Washington Post                   Spirited Away  2001     8.6
# 765   The Washington Post                            2046  2004     7.5
# 909   The Washington Post                Moonrise Kingdom  2012     7.8
# 1614  The Washington Post     Beasts of the Southern Wild  2012     7.3
# 490   The Washington Post                         Boyhood  2014     7.9
# 1432  The Washington Post                   Short Term 12  2013     8.0
# 1850  The Washington Post                         Monster  2003     7.3
#
#      duration  director_id                   name  year_of_birth nationality
# 730    PT157M           74          David Fincher         1962.0         USA
# 1309   PT120M           86                Ang Lee         1954.0      Taiwan
# 308    PT157M           19        Kathryn Bigelow         1951.0         USA
# 221    PT125M           12         Hayao Miyazaki         1941.0       Japan
# 765    PT129M            1           Kar-Wai Wong         1956.0       China
# 909     PT94M           16           Wes Anderson         1969.0         USA
# 1614    PT93M          299           Benh Zeitlin         1982.0         USA
# 490    PT165M           39      Richard Linklater         1960.0         USA
# 1432    PT96M          231  Destin Daniel Cretton         1978.0         USA
# 1850   PT109M          397          Patty Jenkins         1971.0         USA

# %%
df_merged[df_merged['film_id'] == 393]
# Out:
#       critic_id  film_id  rank           full_name nationality_code  \
# 1673         80      393     3  Manuel Kalmanovitz               CO
#
#              company           title  year  rating duration  director_id  \
# 1673  Revista Semana  Sumas y Restas  2004     6.8   PT108M          448
#
#                 name  year_of_birth nationality
# 1673  Victor Gaviria         1955.0    Colombia

# %%
df_genres[df_genres['genre'] == 'Short'].merge(df_films, left_on='film_id', right_index=True)
# Out:
#       film_id  genre                                       title  year  \
# id
# 485       198  Short                           World of Tomorrow  2015
# 764       318  Short                     Capitalism: Child Labor  2007
# 765       319  Short              Psalm III: 'Night of the Meek'  2002
# 766       320  Short                               Daylight Moon  2002
# 767       322  Short                            The Fourth Watch  2000
# 1066      454  Short                                    Lifeline  2002
# 1071      456  Short  Instructions for a Light and Sound Machine  2005
# 1090      466  Short                     Michelangelo Eye to Eye  2004
# 1401      321  Short            A Commuter’s Life (What a Life!)  2014
# 1406      305  Short          Even If She Had Been a Criminal...  2006
#
#       rating duration
# id
# 485      8.2    PT17M
# 764      6.6    PT14M
# 765      7.2    PT24M
# 766      8.9    PT13M
# 767      6.8     PT9M
# 1066     7.6     PT5M
# 1071     6.8    PT17M
# 1090     7.0    PT15M
# 1401     NaN    PT19M
# 1406     7.9     PT9M

# %%
df_directors = pd.read_csv('directors_selenium_raw.csv')

# %%
df_directors[75:85]
# Out:
#     id                name  year_of_birth nationality
# 75  76       Shane Carruth         1972.0         USA
# 76  77       Peter Watkins         1935.0          UK
# 77  79     Carlos Reygadas         1971.0      Mexico
# 78  80         David Lynch         1946.0         USA
# 79  81      Alfonso Cuarón         1961.0      Mexico
# 80  82  Fernando Meirelles         1955.0      Brazil
# 81  83          Kátia Lund         1966.0      Brazil
# 82  84           Brad Bird         1957.0         USA
# 83  85       Guy Bolongaro            NaN         NaN
# 84  86             Ang Lee         1954.0      Taiwan

# %%
df_merged = df_directors.merge(df_countries, left_on='nationality', right_on='name', how='left')

# %%
df_merged[df_merged['code'].isnull()]['nationality'].unique()
# Out:
# array(['China', 'USA', nan, 'UK', 'South Korea', 'Taiwan', 'Yugoslavia',
#        'Palestine'], dtype=object)

# %%
countries = {
    'UK':'GB', 
    'USA':'US', 
    'Palestine':'PS', 
    'Taiwan':'TW', 
    'China':'CN',
    'Yugoslavia':'MK',
    'South Korea':'KR'
}

# %%
df_merged.loc[df_merged['code'].isnull(), 'code'] = df_merged['nationality']

# %%
df_merged['code'].replace(countries, inplace=True)

# %%
df_merged[75:85]
# Out:
#     id              name_x  year_of_birth nationality  name_y code  \
# id
# 75  76       Shane Carruth         1972.0         USA     NaN   US
# 76  77       Peter Watkins         1935.0          UK     NaN   GB
# 77  79     Carlos Reygadas         1971.0      Mexico  Mexico   MX
# 78  80         David Lynch         1946.0         USA     NaN   US
# 79  81      Alfonso Cuarón         1961.0      Mexico  Mexico   MX
# 80  82  Fernando Meirelles         1955.0      Brazil  Brazil   BR
# 81  83          Kátia Lund         1966.0      Brazil  Brazil   BR
# 82  84           Brad Bird         1957.0         USA     NaN   US
# 83  85       Guy Bolongaro            NaN         NaN     NaN  NaN
# 84  86             Ang Lee         1954.0      Taiwan     NaN   TW
#
#    continent_code
# id
# 75            NaN
# 76            NaN
# 77             NA
# 78            NaN
# 79             NA
# 80             SA
# 81             SA
# 82            NaN
# 83            NaN
# 84            NaN

# %%
df_merged[['id', 'name_x', 'year_of_birth', 'code']].to_csv('directors_final.csv', index=False)

# %%
df_films = pd.read_csv('films_selenium_raw.csv')

# %%
df_films.head()
# Out:
#    id                   title  year  rating duration
# 0   0        Mulholland Drive  2001     8.0   PT147M
# 1   1    In the Mood for Love  2000     8.1    PT98M
# 2   2        The Tree of Life  2011     6.8   PT139M
# 3   3  Yi Yi: A One and a Two  2000     8.1   PT173M
# 4   4     Goodbye to Language  2014     5.9    PT70M

# %%
df_films['duration'] = df_films['duration'].str.extract('PT(\d*)M')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   """Entry point for launching an IPython kernel.

# %%
df_films.head()
# Out:
#    id                   title  year  rating duration
# 0   0        Mulholland Drive  2001     8.0      147
# 1   1    In the Mood for Love  2000     8.1       98
# 2   2        The Tree of Life  2011     6.8      139
# 3   3  Yi Yi: A One and a Two  2000     8.1      173
# 4   4     Goodbye to Language  2014     5.9       70

# %%
df_films.to_csv('films_final.csv', index=False)
