# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
page=0

# %%
raw_html = urlopen("https://www.moma.org/collection/?=undefined&page=" + str(page)).read()
soup_doc = BeautifulSoup(raw_html, "html.parser")

# %%
works = soup_doc.find_all(class_='link--tile')

# %%
for w in works:
    print(w)
#     print(w.find('h2'))
#     print(w['href'])
# Out:
# <a class="link--tile" href="/collection/works/221525?locale=en"><div class="thumb-image fpo-image--display-block" role="presentation" tabindex="-1"><div class="thumb-image" fpo_class="fpo-image--display-block"><img alt="" role="presentation" src="" srcset="/media/W1siZiIsIjM5OTI4MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDEyOHgxMjhcdTAwM2UiXV0.jpg?sha=1717c8cba5f7df00 128w, /media/W1siZiIsIjM5OTI4MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDI1NngyNTZcdTAwM2UiXV0.jpg?sha=0801147315d9de43 256w, /media/W1siZiIsIjM5OTI4MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMyMHgzMjBcdTAwM2UiXV0.jpg?sha=43b76faf22ae8faa 320w, /media/W1siZiIsIjM5OTI4MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDUxMng1MTJcdTAwM2UiXV0.jpg?sha=e71d51a24434c0d3 512w"/></div></div>
# <h2 class="tile__caption">
# Martirene Alcántara, Luis Barragán
# <div class="">
# Homage to Luis Barragán: Speculum
#
# </div>
# 2017
# </h2>
# </a>
# ...
